# %% [markdown]
# # Image To Pencil Sketch With Python
# * BY RIDDHI SATARDEKAR

# %% [markdown]
# ## Importing required libraries:

# %%
from google.colab.patches import cv2_imshow
import cv2

# %% [markdown]
# ## Importing the image:

# %%
img = cv2.imread('/content/tiger.jpg', 1)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7FD2F5D51910>

# %% [markdown]
# ## Converting an image into gray_scale image:

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7FD2F5C6FA10>

# %% [markdown]
# ##  Inverting the image:

# %%
img_invert = cv2.bitwise_not(img_gray)
cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7FD2F5C771D0>

# %% [markdown]
# ## Smoothing the image:

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)

cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7FD2F5C77A90>

# %% [markdown]
# ##  Obtaining the final sketch:

# %%
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256)

# %% [markdown]
# ## Final sketch of the loaded image:

# %%
final_img = dodgeV2(img_gray, img_smoothing)
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7FD2F5CC8FD0>

# %%
cv2_imshow(img)
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7FD2F5C65CD0>
# <PIL.Image.Image image mode=L size=225x225 at 0x7FD2F5C65CD0>
